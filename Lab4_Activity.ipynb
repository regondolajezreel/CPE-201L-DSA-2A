# %% [markdown]
# <a href="https://colab.research.google.com/github/regondolajezreel/CPE-201L-DSA-2A/blob/main/Lab4_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class GroceryItem:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def __del__(self):
        pass

    def calculate_sum(self):
        return self.price * self.quantity

    def display(self):
        print(f"{self.name} - ₱ {self.price} × {self.quantity} = ₱ {self.calculate_sum()}")

    def __copy__(self):
        return type(self)(self.name, self.price, self.quantity)

    def copy_assign(self, other):
        self.name = other.name
        self.price = other.price
        self.quantity = other.quantity

class Fruit(GroceryItem):
    pass

class Vegetable(GroceryItem):
    pass

GroceryList = [
    Fruit("Apple", 10, 7),
    Fruit("Banana", 10, 8),
    Vegetable("Broccoli", 60, 12),
    Vegetable("Lettuce", 50, 10)
]

print("--------------------------")
print("Grocery List")
for item in GroceryList:
    item.display()

def TotalSum(grocery_list):
    total = sum(item.calculate_sum() for item in grocery_list)
    return total

print("\nTotal Cost:", TotalSum(GroceryList))

print("\n--------------------------")
print("Removing Lettuce")
GroceryList = [item for item in GroceryList if item.name != "Lettuce"]
print("--------------------------")

print("\nUpdated Grocery List")
for item in GroceryList:
    item.display()
print("--------------------------")
# Out:
# --------------------------
# Grocery List
# Apple - ₱ 10 × 7 = ₱ 70
# Banana - ₱ 10 × 8 = ₱ 80
# Broccoli - ₱ 60 × 12 = ₱ 720
# Lettuce - ₱ 50 × 10 = ₱ 500
#
# Total Cost: 1370
#
# --------------------------
# Removing Lettuce
# --------------------------
#
# Updated Grocery List
# Apple - ₱ 10 × 7 = ₱ 70
# Banana - ₱ 10 × 8 = ₱ 80
# Broccoli - ₱ 60 × 12 = ₱ 720
# --------------------------
